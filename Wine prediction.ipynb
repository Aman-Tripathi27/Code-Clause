# %% [markdown]
# # Wine Prediction
#
# ### Task-2

# %%
#Importing important Libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#Importing CSV file
wp = pd.read_csv("winequalityN.csv")
wp
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# **Collecting information**

# %%
wp.shape
# Out:
# (6497, 13)

# %%
wp.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
wp.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %%
# checking missing values
wp.isna().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# **Filling missing values**

# %%
wp["fixed acidity"].fillna(wp["fixed acidity"].mean(), inplace = True)
wp.isna().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        8
# citric acid             3
# residual sugar          2
# chlorides               2
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      9
# sulphates               4
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wp["volatile acidity"].fillna(wp["volatile acidity"].mean(), inplace = True)
wp["citric acid"].fillna(wp["citric acid"].mean(), inplace = True)
wp["residual sugar"].fillna(wp["residual sugar"].mean(), inplace = True)
wp["chlorides"].fillna(wp["chlorides"].mean(), inplace = True)
wp["pH"].fillna(wp["pH"].mean(), inplace = True)
wp["sulphates"].fillna(wp["sulphates"].mean(), inplace = True)

# %%
wp.isna().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Analysing the data

# %%
wp.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.295751          0.164548     0.145231        4.757392
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035031            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# **Visualising for analysis**

# %%
sns.catplot(x="quality", data = wp, kind="count");

# %%
# Volatile acidity vs Quality
plot = plt.figure(figsize=(5, 7))
sns.barplot(x="quality",
            y = "volatile acidity", 
            data = wp);

# %%
#citric acid vs Quality
plot = plt.figure(figsize=(5, 7))
sns.barplot(x="quality",
            y = "citric acid", 
            data = wp);

# %% [markdown]
# ### Correlation
#
# **Two Types of Correlation**
# 1. Positive Correlation
# 2. Negative Correlation

# %%
wp.drop("type", axis=1, inplace=True)

# %%
# ploting a heatmap to understand the correlation between the columns
correlation = wp.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation, cbar=True, square=True, fmt = '.1f', annot = True, annot_kws={"size":8},cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# ### Preprocessing of data

# %%
X = wp.drop("quality", axis=1)
y = wp["quality"]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ***Making the quality column 0 or 1***

# %%
Y = wp["quality"].apply(lambda y_value: 1 if y_value>=7 else 0)
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6492    0
# 6493    0
# 6494    0
# 6495    0
# 6496    0
# Name: quality, Length: 6497, dtype: int64

# %% [markdown]
# ***Splitting data into Train Test Split***

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,
                                                    Y,
                                                    test_size=0.2,
                                                    random_state=3)

# %%
Y.shape, Y_test.shape, Y_train.shape
# Out:
# ((6497,), (1300,), (5197,))

# %% [markdown]
# ***Model Training***

# %%
model = RandomForestClassifier()
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ***Model Evaluation***

# %%
## Accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
test_data_accuracy
# Out:
# 0.9007692307692308

# %%
A = (6.6,0.16,0.4,1.5,0.044,48,143,0.9912,3.54,0.52,12.4)

#Changing it to numpy array
A_numpy_array = np.asarray(A)

#Reshaping
A_reshaped = A_numpy_array.reshape(1, -1)


prediction = model.predict(A_reshaped)
prediction

if (prediction[0]==1):
    print("Good Quality Wine")
else:
    print("Bad Quality Wine")
# Out:
# Good Quality Wine
